# %%
from transformers import pipeline
image_classifier=pipeline("image-classification")
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# No model was supplied, defaulted to google/vit-base-patch16-224 and revision 3f49326 (https://huggingface.co/google/vit-base-patch16-224).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Device set to use cpu

# %%
from PIL import Image
from matplotlib import pyplot as plt
image=Image.open("/content/cat.1.jpg")
plt.imshow(image)

# %%
image_classifier(image)
# Out:
# [{'label': 'tabby, tabby cat', 'score': 0.6444764137268066},
#  {'label': 'Egyptian cat', 'score': 0.23770223557949066},
#  {'label': 'tiger cat', 'score': 0.10642673075199127},
#  {'label': 'lynx, catamount', 'score': 0.003679887857288122},
#  {'label': 'Siamese cat, Siamese', 'score': 0.0002780919021461159}]

# %%
image_1=Image.open("/content/Raja.jpg")

# %%
plt.imshow(image_1)

# %%
image_classifier(image_1)
# Out:
# [{'label': 'acoustic guitar', 'score': 0.7765098810195923},
#  {'label': 'vestment', 'score': 0.12076787650585175},
#  {'label': 'pick, plectrum, plectron', 'score': 0.014878889545798302},
#  {'label': 'electric guitar', 'score': 0.010165412910282612},
#  {'label': "academic gown, academic robe, judge's robe",
#   'score': 0.005301372613757849}]

# %%
vqa=pipeline("vqa",model="Salesforce/blip-vqa-base")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.54G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# Device set to use cpu

# %%
vqa(image=image_1,question="Is he playing the guitar")
# Out:
# [{'answer': 'yes'}]

# %%
vqa=pipeline("vqa",model="Salesforce/blip-vqa-capfilt-large")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.54G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.54G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/524 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# Device set to use cpu

# %%
### dandelin
### base
### large

# %%
### Image captioning
caption=pipeline("image-to-text")
# Out:
# No model was supplied, defaulted to ydshieh/vit-gpt2-coco-en and revision 5bebf1e (https://huggingface.co/ydshieh/vit-gpt2-coco-en).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/modeling_auto.py:2284: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/236 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/211 [00:00<?, ?B/s]
# Device set to use cpu

# %%
caption(image_1)
# Out:
# [{'generated_text': 'a man in a suit and tie playing a guitar '}]

# %%
### Comeup with an alternate/better

# %%
### Open a new notebook-> Assessment-2

# %%
from transformers import pipeline
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
sentiment_analysis=pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# ...

# %%
sentiment_analysis("I love this training")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998791217803955}]

# %%
sentiment_analysis("I hate this training")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.999627947807312}]

# %%
sentiment_analysis("I love this training but the duration is short")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9865835309028625}]

# %%
sentiment_analysis("The duration is short but still i love this training")
# Out:
# [{'label': 'POSITIVE', 'score': 0.999650239944458}]

# %%
### huggingface.co -> Models-> tasks -> NLP -> Text Classification

# %% [markdown]
# https://huggingface.co/j-hartmann/emotion-english-distilroberta-base

# %%
### Github-> Datasets -> Bank reviews

# %%
### What are the columns? -> Date,Stars(1(negative),5(positive)),Reviews,Bank name

# %%
#### Default-> distilbert base uncased finetuned sst 2 english

#### Predict the sentiment with this default llm and write it excel

# %%
import pandas as pd
df=pd.read_excel("/content/BankReviews.xlsx")

# %%
df.head()
# Out:
#         Date  Stars                                            Reviews  \
# 0 2017-04-10      5  Great job, Wyndham Capital! Each person was pr...
# 1 2017-02-10      5  Matthew Richardson is professional and helpful...
# 2 2017-08-21      5  We had a past experience with Wyndham Mortgage...
# 3 2017-12-17      5  We have been dealing with Brad Thomka from the...
# 4 2016-05-27      5  I can't express how grateful I am for the supp...
#
#                    BankName
# 0  Wyndham Capital Mortgage
# 1  Wyndham Capital Mortgage
# 2  Wyndham Capital Mortgage
# 3  Wyndham Capital Mortgage
# 4  Wyndham Capital Mortgage

# %%
### Filter out the cases where stars and the predicted not matching (some mistakes)

### Try with different llm,-

# %%
## Named Entity Recognition
ner=pipeline("ner",grouped_entities=True)
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496 (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
ner("Premalatha is working as a DataScientist at Amazon,India")
# Out:
# [{'entity_group': 'PER',
#   'score': np.float32(0.9203899),
#   'word': 'Premalatha',
#   'start': 0,
#   'end': 10},
#  {'entity_group': 'ORG',
#   'score': np.float32(0.9854837),
#   'word': 'Amazon',
#   'start': 44,
#   'end': 50},
#  {'entity_group': 'LOC',
#   'score': np.float32(0.9975568),
#   'word': 'India',
#   'start': 51,
#   'end': 56}]

# %%
ner("I love python programming")
# Out:
# []

# %%
ner("Premalatha is working as a DataScientist at amazon,India")
# Out:
# [{'entity_group': 'PER',
#   'score': np.float32(0.9186895),
#   'word': 'Premalatha',
#   'start': 0,
#   'end': 10},
#  {'entity_group': 'ORG',
#   'score': np.float32(0.7197738),
#   'word': 'amazon',
#   'start': 44,
#   'end': 50},
#  {'entity_group': 'LOC',
#   'score': np.float32(0.9981396),
#   'word': 'India',
#   'start': 51,
#   'end': 56}]

# %%
ner("I am from India")
# Out:
# [{'entity_group': 'LOC',
#   'score': np.float32(0.99973565),
#   'word': 'India',
#   'start': 10,
#   'end': 15}]

# %%
### Summarization
summarizer=pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
text=""

# %%
summarizer(text,max_length=60)

# %%
### Chatbot
qa=pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
text="Albert Einstein was a theoretical physicist known for the theory of relativity."

# %%
question="What is Einstein famous for?"

# %%
qa(question=question,context=text)
# Out:
# {'score': 0.3727027475833893,
#  'start': 54,
#  'end': 78,
#  'answer': 'the theory of relativity'}

# %% [markdown]
# deepset_qna=pipeline("question-answering", model="deepset/roberta-base-squad2")

# %%
### gradio-> two tabs(summary,q/a)/pdf/doc
